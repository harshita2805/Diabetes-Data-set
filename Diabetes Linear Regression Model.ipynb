# %% [markdown]
# ## Diabetes Dataset

# %% [markdown]
# #### Giving Random State

# %%
from sklearn import datasets

# %%
data=datasets.load_diabetes()

# %%
c='age sex bmi map tc ldl hdl tch ltg glu'.split()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
diabetes=pd.DataFrame(data.data,columns=c)

# %%
diabetes['target']=data.target

# %%
diabetes
# Out:
#           age       sex       bmi       map        tc       ldl       hdl  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#           tch       ltg       glu  target
# ...

# %%
diabetes.corr()
# Out:
#              age       sex       bmi       map        tc       ldl       hdl  \
# age     1.000000  0.173737  0.185085  0.335427  0.260061  0.219243 -0.075181
# sex     0.173737  1.000000  0.088161  0.241013  0.035277  0.142637 -0.379090
# bmi     0.185085  0.088161  1.000000  0.395415  0.249777  0.261170 -0.366811
# map     0.335427  0.241013  0.395415  1.000000  0.242470  0.185558 -0.178761
# tc      0.260061  0.035277  0.249777  0.242470  1.000000  0.896663  0.051519
# ldl     0.219243  0.142637  0.261170  0.185558  0.896663  1.000000 -0.196455
# hdl    -0.075181 -0.379090 -0.366811 -0.178761  0.051519 -0.196455  1.000000
# tch     0.203841  0.332115  0.413807  0.257653  0.542207  0.659817 -0.738493
# ltg     0.270777  0.149918  0.446159  0.393478  0.515501  0.318353 -0.398577
# glu     0.301731  0.208133  0.388680  0.390429  0.325717  0.290600 -0.273697
# target  0.187889  0.043062  0.586450  0.441484  0.212022  0.174054 -0.394789
#
# ...

# %%
import seaborn as sns
sns.heatmap(diabetes.corr())
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(diabetes,data.target,test_size = 0.25,random_state = 101)

# %%
from sklearn import  linear_model

# %%
x_train
# Out:
#           age       sex       bmi       map        tc       ldl       hdl  \
# 176  0.045341  0.050680  0.019662  0.039087  0.020446  0.025930  0.008142
# 104 -0.027310 -0.044642  0.064930 -0.002228 -0.024960 -0.017284  0.022869
# 201 -0.034575  0.050680 -0.055785 -0.015999 -0.009825 -0.007890  0.037595
# 309 -0.009147  0.050680  0.001339 -0.002228  0.079612  0.070084  0.033914
# 380  0.016281 -0.044642  0.026128  0.058596 -0.060735 -0.044215 -0.013948
# ..        ...       ...       ...       ...       ...       ...       ...
# 63  -0.034575 -0.044642 -0.037463 -0.060757  0.020446  0.043466 -0.013948
# 326  0.045341  0.050680 -0.008362 -0.033214 -0.007073  0.001191 -0.039719
# 337  0.019913  0.050680 -0.012673  0.070073 -0.011201  0.007141 -0.039719
# 11   0.027178  0.050680  0.017506 -0.033214 -0.007073  0.045972 -0.065491
# 351 -0.085430  0.050680 -0.040696 -0.033214 -0.081374 -0.069580 -0.006584
#
#           tch       ltg       glu  target
# ...

# %%
x_test
# Out:
#           age       sex       bmi       map        tc       ldl       hdl  \
# 12   0.016281 -0.044642 -0.028840 -0.009113 -0.004321 -0.009769  0.044958
# 19  -0.027310 -0.044642 -0.018062 -0.040099 -0.002945 -0.011335  0.037595
# 139  0.023546 -0.044642  0.061696  0.052858 -0.034592 -0.048912 -0.028674
# 143 -0.030942 -0.044642  0.005650 -0.009113  0.019070  0.006828  0.074412
# 155 -0.027310  0.050680  0.060618  0.049415  0.085116  0.086368 -0.002903
# ..        ...       ...       ...       ...       ...       ...       ...
# 358 -0.020045 -0.044642 -0.084886 -0.026328 -0.035968 -0.034194  0.041277
# 15  -0.052738  0.050680 -0.018062  0.080401  0.089244  0.107662 -0.039719
# 153  0.041708  0.050680 -0.043929  0.063187 -0.004321  0.016222 -0.013948
# 13   0.005383  0.050680 -0.001895  0.008101 -0.004321 -0.015719 -0.002903
# 167  0.070769 -0.044642  0.069241  0.037939  0.021822  0.001504 -0.036038
#
#           tch       ltg       glu  target
# ...

# %%
y_test
# Out:
# array([179., 168., 281.,  60., 186., 258., 317., 140., 152., 134., 115.,
#        164.,  72., 128., 129., 281., 199., 197., 275.,  60., 232.,  84.,
#        173.,  83., 162., 172., 245.,  44., 202., 104., 168., 178., 141.,
#        103.,  59., 274., 185.,  90.,  72., 281., 154.,  64., 253., 242.,
#        252.,  47., 108., 346., 190., 137., 118.,  25.,  54.,  51.,  59.,
#         67.,  71.,  91., 184., 110., 111.,  80.,  45., 263., 180.,  79.,
#         90., 144.,  92., 265.,  92., 217., 336., 208., 122., 281., 272.,
#         52., 258.,  49., 148., 104., 160.,  94., 143.,  51., 225., 135.,
#        257.,  71.,  63., 179., 219.,  84.,  70., 200.,  42.,  77.,  99.,
#        249., 230., 196., 163.,  75., 128.,  97.,  90., 171.,  71., 185.,
#        220.])

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()
model=LR.fit(x_train, y_train)
YPrediction=model.predict(x_test)
YPrediction
# Out:
# array([179., 168., 281.,  60., 186., 258., 317., 140., 152., 134., 115.,
#        164.,  72., 128., 129., 281., 199., 197., 275.,  60., 232.,  84.,
#        173.,  83., 162., 172., 245.,  44., 202., 104., 168., 178., 141.,
#        103.,  59., 274., 185.,  90.,  72., 281., 154.,  64., 253., 242.,
#        252.,  47., 108., 346., 190., 137., 118.,  25.,  54.,  51.,  59.,
#         67.,  71.,  91., 184., 110., 111.,  80.,  45., 263., 180.,  79.,
#         90., 144.,  92., 265.,  92., 217., 336., 208., 122., 281., 272.,
#         52., 258.,  49., 148., 104., 160.,  94., 143.,  51., 225., 135.,
#        257.,  71.,  63., 179., 219.,  84.,  70., 200.,  42.,  77.,  99.,
#        249., 230., 196., 163.,  75., 128.,  97.,  90., 171.,  71., 185.,
#        220.])

# %%
slope=model.coef_ 
intercept=model.intercept_
slope
# Out:
# array([-1.91079477e-13,  1.00076696e-12,  4.67749870e-13, -7.52111046e-14,
#        -6.01568301e-14,  6.17460161e-14,  3.34527943e-14,  4.40130797e-14,
#        -1.50571188e-13, -3.89003953e-14,  1.00000000e+00])

# %%
intercept
# Out:
# -5.684341886080802e-14

# %%
from sklearn.metrics import r2_score
r2score=r2_score(y_test, YPrediction)
r2score
# Out:
# 1.0

# %% [markdown]
# #### Without Random State

# %%
from sklearn import datasets
data=datasets.load_diabetes()

# %%
c='age sex bmi map tc ldl hdl tch ltg glu'.split()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
diabetes=pd.DataFrame(data.data,columns=c)

# %%
diabetes['target']=data.target
diabetes
# Out:
#           age       sex       bmi       map        tc       ldl       hdl  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#           tch       ltg       glu  target
# ...

# %%
from sklearn.model_selection import train_test_split
x_train1,x_test1,y_train1,y_test1 = train_test_split(diabetes,data.target,test_size = 0.25)

# %%
from sklearn import  linear_model

# %%
x_train1
# Out:
#           age       sex       bmi       map        tc       ldl       hdl  \
# 427 -0.034575  0.050680  0.005650 -0.005671 -0.073119 -0.062691 -0.006584
# 262 -0.016412  0.050680  0.127443  0.097616  0.016318  0.017475 -0.021311
# 250  0.067136 -0.044642  0.056307  0.073515 -0.013953 -0.039205 -0.032356
# 292  0.009016 -0.044642 -0.022373 -0.032066 -0.049727 -0.068641  0.078093
# 241  0.030811  0.050680 -0.008362  0.004658  0.014942  0.027496  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 154  0.067136  0.050680  0.020739 -0.005671  0.020446  0.026243 -0.002903
# 229 -0.027310  0.050680 -0.015906 -0.029771  0.003935 -0.000688  0.041277
# 40   0.005383  0.050680 -0.008362  0.021872  0.054845  0.073215 -0.024993
# 252  0.005383 -0.044642  0.059541 -0.056166  0.024574  0.052861 -0.043401
# 151  0.001751 -0.044642 -0.004050 -0.005671 -0.008449 -0.023861  0.052322
#
#           tch       ltg       glu  target
# ...

# %%
y_train1
# Out:
# array([ 67., 308., 303.,  84., 177.,  97.,  42., 219., 134., 110., 178.,
#        220., 274., 265., 173., 144., 118.,  65.,  54., 122., 262., 129.,
#         77., 277., 137., 151., 131.,  59., 217., 107., 233.,  63., 109.,
#         81.,  87., 214.,  84., 264., 109., 225., 150.,  48.,  73., 178.,
#         71., 281., 283., 198., 235., 202., 202., 143., 142.,  70.,  90.,
#        142., 310., 279., 275., 104., 232.,  92.,  72., 243., 222., 170.,
#        265., 124.,  65., 196., 214., 192., 139.,  72., 121., 245., 173.,
#        246., 225., 230.,  71.,  69., 219.,  49., 163., 200.,  55., 148.,
#         77., 155., 170., 111., 184.,  71., 156., 128., 138.,  98., 281.,
#         99., 164.,  60., 248., 162., 277., 180., 137.,  60., 118., 128.,
#        214., 236., 186., 243., 197., 257., 257., 200., 190.,  94.,  65.,
#        172.,  59., 258., 248., 103.,  85.,  49., 208., 270.,  91., 111.,
#         77.,  51.,  68.,  83., 252.,  48., 258., 101., 160., 135., 182.,
# ...

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()
model=LR.fit(x_train1, y_train1)
YPrediction1=model.predict(x_test1)
YPrediction1
# Out:
# array([ 92., 116., 131., 249., 292., 206., 127.,  69., 142.,  83., 281.,
#        196., 200., 293., 242., 268., 132., 244.,  93., 127., 115., 178.,
#        104., 144.,  52.,  67., 200., 220., 270., 110., 160., 292., 191.,
#        273., 138.,  88., 143., 283.,  40., 152., 121.,  86., 124., 262.,
#         75.,  51., 261.,  60., 306., 174., 153., 180., 201.,  90., 276.,
#        295.,  84.,  53.,  69., 132., 116., 253., 168., 233.,  39.,  90.,
#        136., 198.,  51.,  68.,  48., 275., 141.,  96., 114., 182.,  81.,
#        134.,  94., 200., 199.,  88.,  72.,  47., 129., 172.,  59., 302.,
#         55., 151., 167., 109., 125.,  71., 115., 281.,  64.,  74., 246.,
#        275., 288., 241., 141., 212., 141.,  52., 171.,  85., 102., 268.,
#        131.])

# %%
from sklearn.metrics import r2_score
r2score=r2_score(y_test1, YPrediction1)
r2score
# Out:
# 1.0

# %% [markdown]
# Collinearity find by [Vif(variance inflation factor)]-Through this we find amount of multicollinearity in multiple regression variable.Its value goes upto 5. If 5 then its high.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
from sklearn import datasets
data=datasets.load_diabetes()
c='age sex bmi map tc ldl hdl tch ltg glu'.split()
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
diabetes=pd.DataFrame(data.data,columns=c)

# %%
x=diabetes
x
# Out:
#           age       sex       bmi       map        tc       ldl       hdl  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#           tch       ltg       glu
# 0   -0.002592  0.019908 -0.017646
# ...

# %%
y=data.target
y
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
# ...

# %%
vif_=pd.DataFrame()

# %%
vif_['F']=x.columns
vif_['vif']=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif_
# Out:
#      F        vif
# 0  age   1.217307
# 1  sex   1.278073
# 2  bmi   1.509446
# 3  map   1.459429
# 4   tc  59.203786
# 5  ldl  39.194379
# 6  hdl  15.402352
# 7  tch   8.890986
# 8  ltg  10.076222
# 9  glu   1.484623

# %%
from sklearn.metrics import mean_absolute_error

# %%
mae=mean_absolute_error(y_test1, YPrediction1)
mae
# Out:
# 1.830767769616114e-14

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error=(y_test1, YPrediction1)
mse
# Out:
# (array([ 92., 116., 131., 249., 292., 206., 127.,  69., 142.,  83., 281.,
#         196., 200., 293., 242., 268., 132., 244.,  93., 127., 115., 178.,
#         104., 144.,  52.,  67., 200., 220., 270., 110., 160., 292., 191.,
#         273., 138.,  88., 143., 283.,  40., 152., 121.,  86., 124., 262.,
#          75.,  51., 261.,  60., 306., 174., 153., 180., 201.,  90., 276.,
#         295.,  84.,  53.,  69., 132., 116., 253., 168., 233.,  39.,  90.,
#         136., 198.,  51.,  68.,  48., 275., 141.,  96., 114., 182.,  81.,
#         134.,  94., 200., 199.,  88.,  72.,  47., 129., 172.,  59., 302.,
#          55., 151., 167., 109., 125.,  71., 115., 281.,  64.,  74., 246.,
#         275., 288., 241., 141., 212., 141.,  52., 171.,  85., 102., 268.,
#         131.]),
#  array([ 92., 116., 131., 249., 292., 206., 127.,  69., 142.,  83., 281.,
#         196., 200., 293., 242., 268., 132., 244.,  93., 127., 115., 178.,
# ...

# %%
from sklearn.metrics import mean_squared_error
rmse1=mean_squared_error=(y_test1, YPrediction1)
rmse1
# Out:
# (array([ 92., 116., 131., 249., 292., 206., 127.,  69., 142.,  83., 281.,
#         196., 200., 293., 242., 268., 132., 244.,  93., 127., 115., 178.,
#         104., 144.,  52.,  67., 200., 220., 270., 110., 160., 292., 191.,
#         273., 138.,  88., 143., 283.,  40., 152., 121.,  86., 124., 262.,
#          75.,  51., 261.,  60., 306., 174., 153., 180., 201.,  90., 276.,
#         295.,  84.,  53.,  69., 132., 116., 253., 168., 233.,  39.,  90.,
#         136., 198.,  51.,  68.,  48., 275., 141.,  96., 114., 182.,  81.,
#         134.,  94., 200., 199.,  88.,  72.,  47., 129., 172.,  59., 302.,
#          55., 151., 167., 109., 125.,  71., 115., 281.,  64.,  74., 246.,
#         275., 288., 241., 141., 212., 141.,  52., 171.,  85., 102., 268.,
#         131.]),
#  array([ 92., 116., 131., 249., 292., 206., 127.,  69., 142.,  83., 281.,
#         196., 200., 293., 242., 268., 132., 244.,  93., 127., 115., 178.,
# ...
